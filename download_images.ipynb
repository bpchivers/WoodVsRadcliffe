# %%
import torch
from fastai import *
from fastai.vision import *

# %%
folder = 'wood'
file = 'urls_wood.txt'
path = Path('data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
max_pics=10

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:06<00:00]
#     </div>
# Error https://www.deseretnews.com/images/article/hires/700462977/700462977.jpg 'content-length'
# Error https://wealthsimple-grow.ghost.io/content/images/2017/08/ElijahWood_final-2800.jpg 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fewedit.files.wordpress.com%2F2016%2F05%2Fharry-baggins.jpg%3Fw%3D612&w=1000&c=sc&poi=face&q=70 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=10006554849 'content-length'
# Error https://d.ibtimes.co.uk/en/full/1619108/tommy-corbyn.jpg?w=400&h=452&l=50&t=40&e=7d20870931a2153e2dd695a6c429f1d6 'content-length'
# Error https://parade.com/wp-content/uploads/2014/01/elijah-wood-the-good-son.jpg 'content-length'
# Error https://www.syfy.com/sites/syfy/files/wire/legacy/Elijah-Wood.jpg 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fewedit.files.wordpress.com%2F2015%2F01%2Felijah-wood_240.jpg%3Fw%3D240&w=1000&c=sc&poi=face&q=70 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2016%2F08%2Felijah-wood-435-4.jpg%3Fw%3D435&w=700&c=sc&poi=face&q=85 'content-length'
# Error https://bloximages.chicago2.vip.townnews.com/heraldextra.com/content/tncms/assets/v3/editorial/7/a6/7a697669-817e-5d75-9c77-d5f775247bdc/5991bb6c55c61.image.jpg?resize=1200%2C798 'content-length'
# Error http://staticimg.stantondaily.com/wp-content/uploads/Elijah-Wood.jpg 'content-length'
# Error https://41z6h24c86pu1h3m6x151ecm-wpengine.netdna-ssl.com/wp-content/uploads/2015/10/elijahwood-12-272x408.jpg 'content-length'
# Error https://tranzgender.com/wp-content/uploads/2016/06/Elijah-Wood-transgender.png HTTPSConnectionPool(host='tranzgender.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/06/Elijah-Wood-transgender.png (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1230b2cc0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Error https://c8.alamy.com/comp/F13G3R/berlin-germany-26th-aug-2015-us-actor-elijah-wood-poses-on-the-grounds-F13G3R.jpg 'content-length'

# %%
folder = 'radcliffe'
file = 'urls_radcliffe.txt'
path = Path('data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:14<00:00]
#     </div>
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2016%2F08%2Fdaniel-radcliffe-600x450-3.jpg%3Fw%3D600&w=700&c=sc&poi=face&q=85 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2016%2F08%2Fdaniel-radcliffe-435-37.jpg%3Fw%3D435&w=700&c=sc&poi=face&q=85 'content-length'
# Error https://imagesvc.timeincapp.com/v3/fan/image?url=https://wizardsandwhatnot.com/wp-content/uploads/getty-images/2016/07/543378156-the-apple-store-presents-daniel-radcliffe-and-paul-dano-swiss-army-man-850x560.jpg&c=sc&w=850&h=560 'content-length'
# Error https://www.fan-lexikon.de/film-tv/daniel-radcliffe/bilder/l/daniel-radcliffe-5279.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1330266643699713 'content-length'
# Error http://images.mid-day.com/images/2015/jul/23-Daniel-Radcliffe-Harry-P.jpg 'content-length'
# Error https://imagesvc.timeincapp.com/v3/fan/image?url=https%3A%2F%2Fwizardsandwhatnot.com%2Fwp-content%2Fuploads%2Fgetty-images%2F2016%2F09%2F601094450-imperium-premiere-42nd-deauville-american-film-festival.jpg&c=sc&w=850&h=560 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fewedit.files.wordpress.com%2F2016%2F06%2Fdaniel-radcliffe-1.jpg%3Fw%3D612&w=1000&c=sc&poi=face&q=70 'content-length'

# %%
classes = ['wood','radcliffe']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# wood
#     <div>
#       <progress value='187' max='187', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [187/187 00:03<00:00]
#     </div>
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/.DS_Store'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000070.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000104.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000111.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000115.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000134.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000083.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/wood/00000195.jpg'
# radcliffe
#     <div>
#       <progress value='223' max='223', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [223/223 00:06<00:00]
#     </div>
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000011.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000007.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000111.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000090.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000096.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000043.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000193.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000144.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000147.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000194.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000182.jpg'
# cannot identify image file '/Users/bpc_msds2019/Documents/Data Institute/Deep Learning Part 1/course_work/WoodVsRadcliffe/data/radcliffe/00000155.jpg'

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['radcliffe', 'wood']

# %%
data.show_batch(rows=3, figsize=(7,8))
